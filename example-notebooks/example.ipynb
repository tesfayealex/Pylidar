# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('../src/')))
from lidar_data_processor import Lidar_Processor
from lidar_data_visualizer import Lidar_Visualizer

# %%
polygon_array= [446112.3120340019  , 4652575.060161518 , 447610.6998241764,4654067.900678839]
processor = Lidar_Processor(polygon_array=polygon_array , epsg=26915)
geo_df , tiff_file_path , pipeline_array = processor.fetch_file()
geo_df
# Out:
#          elevation                        geometry
# 0           272.51  POINT (447489.490 4653264.749)
# 1           272.44  POINT (447485.816 4653264.776)
# 2           272.36  POINT (447480.797 4653264.850)
# 3           272.39  POINT (447482.629 4653265.185)
# 4           272.48  POINT (447488.080 4653266.219)
# ...            ...                             ...
# 1439566     280.98  POINT (446403.529 4652585.479)
# 1439567     282.08  POINT (446338.101 4652585.336)
# 1439568     282.19  POINT (446271.660 4652586.128)
# 1439569     282.78  POINT (446206.280 4652586.535)
# 1439570     287.26  POINT (446140.131 4652581.657)
#
# [1439571 rows x 2 columns]

# %%
visualizer = Lidar_Visualizer(geo_df , tiff_file_path)

# %%
visualizer.plot_3d_terrain()

# %%
visualizer.plot_2d_image()

# %%
visualizer.plot_geopandas()

# %%
visualizer.plot_image_with_affine_transform()

# %%
visualizer.plot_image_with_contour()

# %%
visualizer.plot_histogram_of_raster()

# %%
visualizer.plot_grey_rbg_with_histogram()
